# %%
import pandas as pd

# %%
stock_data = pd.read_csv("2002 Nov-2003 Oct.csv")
stock_data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2002-11-01  885.760010  903.419983  877.710022  900.960022  900.960022
# 1  2002-11-04  900.960022  924.580017  900.960022  908.349976  908.349976
# 2  2002-11-05  908.349976  915.830017  904.909973  915.390015  915.390015
# 3  2002-11-06  915.390015  925.659973  905.000000  923.760010  923.760010
# 4  2002-11-07  923.760010  923.760010  898.679993  902.650024  902.650024
#
#        Volume
# 0  1450400000
# 1  1645900000
# 2  1354100000
# 3  1674000000
# 4  1466900000

# %%
stock_data = stock_data.set_index("Date")

# %%
stock_data["Volume"].plot(kind="line")

# %%
stock_data["Adj Close"].plot(kind="line")
