# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sars_data = pd.read_csv("sars_2003_complete_dataset_clean.csv")
sars_data
# Out:
#             Date               Country  Cumulative number of case(s)  \
# 0     2003-03-17               Germany                             1
# 1     2003-03-17                Canada                             8
# 2     2003-03-17             Singapore                            20
# 3     2003-03-17  Hong Kong SAR, China                            95
# 4     2003-03-17           Switzerland                             2
# ...          ...                   ...                           ...
# 2533  2003-07-11           Switzerland                             1
# 2534  2003-07-11              Thailand                             9
# 2535  2003-07-11        United Kingdom                             4
# 2536  2003-07-11         United States                            75
# 2537  2003-07-11              Viet Nam                            63
#
#       Number of deaths  Number recovered
# 0                    0                 0
# 1                    2                 0
# ...

# %%
sars_data.head()
# Out:
#          Date               Country  Cumulative number of case(s)  \
# 0  2003-03-17               Germany                             1
# 1  2003-03-17                Canada                             8
# 2  2003-03-17             Singapore                            20
# 3  2003-03-17  Hong Kong SAR, China                            95
# 4  2003-03-17           Switzerland                             2
#
#    Number of deaths  Number recovered
# 0                 0                 0
# 1                 2                 0
# 2                 0                 0
# 3                 1                 0
# 4                 0                 0

# %%
keep_columns = ["Date","Cumulative number of case(s)","Number of deaths","Number recovered"]

sars_data1 = sars_data[keep_columns]
sars_data1
# Out:
#             Date  Cumulative number of case(s)  Number of deaths  \
# 0     2003-03-17                             1                 0
# 1     2003-03-17                             8                 2
# 2     2003-03-17                            20                 0
# 3     2003-03-17                            95                 1
# 4     2003-03-17                             2                 0
# ...          ...                           ...               ...
# 2533  2003-07-11                             1                 0
# 2534  2003-07-11                             9                 2
# 2535  2003-07-11                             4                 0
# 2536  2003-07-11                            75                 0
# 2537  2003-07-11                            63                 5
#
#       Number recovered
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# ...

# %%
sars_data2 = sars_data1.sort_values("Date",ascending = True)
sars_data2
# Out:
#             Date  Cumulative number of case(s)  Number of deaths  \
# 0     2003-03-17                             1                 0
# 1     2003-03-17                             8                 2
# 2     2003-03-17                            20                 0
# 3     2003-03-17                            95                 1
# 4     2003-03-17                             2                 0
# ...          ...                           ...               ...
# 2508  2003-07-11                           250                38
# 2507  2003-07-11                             1                 0
# 2536  2003-07-11                            75                 0
# 2521  2003-07-11                             5                 2
# 2537  2003-07-11                            63                 5
#
#       Number recovered
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# ...

# %%
sars_data3 = sars_data2.groupby(sars_data2["Date"]).sum()
sars_data3
# Out:
#             Cumulative number of case(s)  Number of deaths  Number recovered
# Date
# 2003-03-17                           167                 4                 0
# 2003-03-18                           219                 4                 0
# 2003-03-19                           264                 9                 0
# 2003-03-20                           306                10                 0
# 2003-03-21                           350                10                 0
# ...                                  ...               ...               ...
# 2003-07-07                          8434               812              7426
# 2003-07-08                          8431               812              7428
# 2003-07-09                          8431               812              7438
# 2003-07-10                          8432               812              7444
# 2003-07-11                          8432               813              7447
#
# [96 rows x 3 columns]

# %%
sars_data3["Daily case(s)"] = sars_data3["Cumulative number of case(s)"].diff()
sars_data3
# Out:
#             Cumulative number of case(s)  Number of deaths  Number recovered  \
# Date
# 2003-03-17                           167                 4                 0
# 2003-03-18                           219                 4                 0
# 2003-03-19                           264                 9                 0
# 2003-03-20                           306                10                 0
# 2003-03-21                           350                10                 0
# ...                                  ...               ...               ...
# 2003-07-07                          8434               812              7426
# 2003-07-08                          8431               812              7428
# 2003-07-09                          8431               812              7438
# 2003-07-10                          8432               812              7444
# 2003-07-11                          8432               813              7447
#
#             Daily case(s)
# Date
# ...

# %%
sars_data4 = sars_data3.loc[sars_data3["Daily case(s)"]>=0]
sars_data4
# Out:
#             Cumulative number of case(s)  Number of deaths  Number recovered  \
# Date
# 2003-03-18                           219                 4                 0
# 2003-03-19                           264                 9                 0
# 2003-03-20                           306                10                 0
# 2003-03-21                           350                10                 0
# 2003-03-22                           386                11                 0
# ...                                  ...               ...               ...
# 2003-07-04                          8434               812              7426
# 2003-07-07                          8434               812              7426
# 2003-07-09                          8431               812              7438
# 2003-07-10                          8432               812              7444
# 2003-07-11                          8432               813              7447
#
#             Daily case(s)
# Date
# ...

# %%
sars_data3["Daily case(s)"].plot(kind="line")

# %% [raw]
# fig.savefig('name.png')
